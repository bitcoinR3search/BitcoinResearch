# %%
import matplotlib.pyplot as plt
from app.readata import *
import os
import numpy
#current_dir = os.getcwd()
os.chdir('/home/richard/TRABAJO/BitcoinResearch/scripts/')
estado_data()
transacciones=leer_data('ntx')
numero=leer_data('n_block')
print(transacciones)
plt.plot(numero,transacciones)
plt.show()
# Out:
# Last block: 798268
# Variables :n_block, time_b, size, ntx, bits, chainwork, strippedsize, weight, total
# [1.000e+00 1.000e+00 1.000e+00 ... 3.323e+03 2.852e+03 2.037e+03]

# %%
print(9//2)
arreglo1=[1,-2,3,4,-5,6,7,8]
#arreglo2=arreglo1[arreglo1>0]
print(arreglo1[2:])
print(np.abs(arreglo1))
# Out:
# 4
# [3, 4, -5, 6, 7, 8]
# [1 2 3 4 5 6 7 8]
